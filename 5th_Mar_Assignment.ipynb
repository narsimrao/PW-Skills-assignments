# %%
# !pip install bokeh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

from bokeh.plotting import figure, output_file, show 
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Q1

# %%
"""
How can you create a Bokeh plot using Python code?
"""

# %%
output_file("test.html")

p = figure(title = "test flower")
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"

p.circle(flowers["petal_length"],flowers["petal_width"])
show(p)
# Out:
#   <div class="bk-root" id="0a7d046f-253e-4745-b036-cb6137cec7c5" data-root-id="1158"></div>

# %% [markdown]
# # Q2

# %%
"""
What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.
"""

# %%
"""
a glyph is a visual shape used to represent data on a plot. 
It can be any shape or marker such as a circle, square, line, or triangle.

Glyphs are added to a Bokeh plot using the figure() function
"""
output_file("test.html")
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]

p = figure()
p.circle(x, y,size=10, color='red')
show(p)
# Out:
#   <div class="bk-root" id="467c2bfa-1830-4134-9e82-ac689a4af6ba" data-root-id="1646"></div>

# %% [markdown]
# # Q3

# %%
"""
How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?
"""

# %%
output_file("test.html")

p = figure(plot_width=800, plot_height=400)

x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]

p.xaxis.axis_label = 'X-axis Label'
p.xaxis.axis_label_text_font_size = '14pt'

p.title.text = 'Title'
p.title.text_font_size = '16pt'

p.legend.label_text_font_size = '12pt'
p.legend.location = 'top_left'

p.circle(x, y,size=10, color='red')
show(p)
# Out:
#   <div class="bk-root" id="83aadd6a-f104-4b93-a37f-a85898e2e6ac" data-root-id="2217"></div>

# %% [markdown]
# # Q4

# %%
"""
What is a Bokeh server, and how can you use it to create interactive plots that can be updated in real time?
"""

# %%
"""
A Bokeh server is a Python process that allows the creation of interactive Bokeh plots that can be updated in real-time. 
It provides a way to build web applications that can generate and modify Bokeh visualizations dynamically, 
allowing for interactive exploration of data.


To create a Bokeh application, you first need to define the layout of the plot using Bokeh models,
 such as Figure, ColumnDataSource, and various glyphs (e.g., Circle, Line, Patch)
"""

# %% [markdown]
# # Q5

# %%
"""
How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?
"""

# %%
"""
Bokeh plots can be embedded in Flask or Django web applications using the components function from the bokeh.embed module. 
This function generates the necessary HTML and JavaScript code to embed a Bokeh plot in a web page.
"""
