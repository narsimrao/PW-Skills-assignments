# %% [markdown]
# # Q1

# %%
"""
Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.
"""

# %%
import scipy.stats as stats

data = [50]  # sample data
n = len(data)  # sample size
mean = sum(data) / n  # sample mean
std_dev = 5  # population standard deviation

# Calculate the standard error
std_error = std_dev / (n ** 0.5)

# The 95% confidence Interval can be given as mean ± 1.96*SE
margin_error = 1.96 * std_error
# Calculate the confidence interval
lower_bound = mean - margin_error
upper_bound = mean + margin_error

print("The 95% confidence interval is: ({:.2f}, {:.2f})".format(lower_bound, upper_bound))
# Out:
# The 95% confidence interval is: (40.20, 59.80)

# %% [markdown]
# # Q2

# %%
"""
Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag matches the expected distribution of 
20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20% brown. 
Use Python to perform the test with a significance level of 0.05.
"""

# %%
import scipy.stats as stat
import numpy as np

observed_data = [8, 7, 9, 5, 10, 8]
expected_data = [0.2*47, 0.2*47, 0.2*47, 0.1*47, 0.1*47, 0.2*47]

## Chi square Goodness OF Fit
chisquare_test_statistics,p_value=stat.chisquare(observed_data,expected_data)

significance=0.05
dof=len(observed_data)-1
critical_value=stat.chi2.ppf(1-significance,dof)

if chisquare_test_statistics > critical_value:
    print("Reject the null hypothesis")
else:
    print("Accept the null hypothesis")
# Out:
# Accept the null hypothesis

# %% [markdown]
# # Q3

# %% [markdown]
# ![download.png](attachment:59703342-9630-41cd-b3bc-38e67d52844b.png)

# %%
observed_data = [20,15,10,25,15,20]
"""
Expected = (row_total*column_total)/grand_total
"""

expected_data = [(35*45)/105,(35*60)/105,(35*45)/105,(35*60)/105,(35*45)/105,(35*60)/105]

chisquare_test_statistics,p_value=stat.chisquare(observed_data,expected_data)
print(chisquare_test_statistics, p_value)
# Out:
# 5.833333333333334 0.32277564078959387

# %% [markdown]
# # Q4

# %%
"""
A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals smoked. 
Use Python to calculate the 95% confidence interval for the true proportion of individuals in the population who smoke.
"""

# %%
import math
import scipy.stats as stats

n = 500
x = 60
p = x/n
se = math.sqrt(p*(1-p)/n)
cv = stats.norm.ppf(0.975)
me = cv * se
ci = (p - me, p + me)

print("95% Confidence Interval: ", ci)
# Out:
# 95% Confidence Interval:  (0.09151638887130707, 0.1484836111286929)

# %% [markdown]
# # Q5

# %%
"""
Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation of 12 using Python. 
Interpret the results.
"""

# %%
from scipy import stats

data = [75] # sample data
n = len(data) # sample size
mean = sum(data) / n # sample mean
stddev = 12 # population standard deviation

t_value = stats.t.ppf(0.95, n-1)
margin_error = t_value * (stddev / (n ** 0.5))
confidence_interval = (mean - margin_error, mean + margin_error)

print("90% Confidence Interval:", confidence_interval)
# Out:
# 90% Confidence Interval: (nan, nan)

# %% [markdown]
# # Q6

# %%
"""
Use Python to plot the chi-square distribution with 10 degrees of freedom. 
Label the axes and shade the area corresponding to a chi-square statistic of 15.
"""

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

df = 10 # degrees of freedom
x = np.linspace(0, 30, 1000)
y = chi2.pdf(x, df)

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, y, label='Chi-Square PDF')
ax.fill_between(x[x >= 15], y[x >= 15], 0, alpha=0.5, label='Area: Chi-Square > 15')
ax.set_title(f'Chi-Square Distribution with {df} Degrees of Freedom')
ax.set_xlabel('Chi-Square Statistic')
ax.set_ylabel('Probability Density')
ax.legend()
plt.show()

# %% [markdown]
# # Q7

# %%
"""
A random sample of 1000 people was asked if they preferred Coke or Pepsi. 
Of the sample, 520 preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who prefer Coke.
"""

# %%
import statsmodels.stats.proportion as smp

# Calculate the confidence interval
lower, upper = smp.proportion_confint(520, 1000, alpha=0.05, method='normal')

# Print the results
print(f"({lower}, {upper})")
# Out:
# (0.48903505011072596, 0.5509649498892741)

# %% [markdown]
# # Q8

# %%
"""
A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe 45 tails. 
Conduct a chi-square goodness of fit test to determine if the observed frequencies match the expected frequencies of a fair coin. 
Use a significance level of 0.05.
"""

# %%
import scipy.stats as stats

# null hypothesis : coin is not fair
# alternate hypothesis: coin is fair
observed_freq = [55, 45]  # number of heads, number of tails
expected_freq = [50, 50]  # expected number of heads, expected number of tails

chi2_statistic, p_value = stats.chisquare(observed_freq, expected_freq)

print("Chi-square statistic:", chi2_statistic)
print("p-value:", p_value)

significance=0.05
dof=len(observed_freq)-1
critical_value=stat.chi2.ppf(1-significance,dof)

if chisquare_test_statistics > critical_value:
    print("Reject the null hypothesis")
else:
    print("Accept the null hypothesis")
# Out:
# Chi-square statistic: 1.0
# p-value: 0.31731050786291115
# Reject the null hypothesis

# %% [markdown]
# # Q9

# %% [markdown]
# ![image.png](attachment:8845767e-94ba-4477-a68d-377f7c814c28.png)

# %%
observed_data = np.array([60,140,30,170])
"""
Expected = (row_total*column_total)/grand_total
"""

expected_data = np.array([(200*90)/400,(200*310)/400,(200*90)/400,(200*310)/400])

chisquare_test_statistics,p_value=stat.chisquare(observed_data,expected_data)

print("Chi-square statistic:", chisquare_test_statistics)
print("p-value:", p_value)

significance=0.05
dof=len(observed_freq)-1
critical_value=stat.chi2.ppf(1-significance,dof)

if chisquare_test_statistics > critical_value:
    print("Reject the null hypothesis")
else:
    print("Accept the null hypothesis")
# Out:
# Chi-square statistic: 12.903225806451612
# p-value: 0.004850628276023122
# Reject the null hypothesis

# %% [markdown]
# # Q10

# %% [markdown]
# ![image.png](attachment:1cede990-dc88-4b25-9560-05611d43f96b.png)

# %%
observed_data = np.array([200,150,150,225,175,100])
"""
Expected = (row_total*column_total)/grand_total
"""

expected_data = np.array([(500*425)/1000,(500*325)/1000,(500*250)/1000,(500*425)/1000,(500*325)/1000,(500*250)/1000])

chisquare_test_statistics,p_value=stat.chisquare(observed_data,expected_data)

print("Chi-square statistic:", chisquare_test_statistics)
print("p-value:", p_value)

significance=0.01
dof=len(observed_freq)-1
critical_value=stat.chi2.ppf(1-significance,dof)

if chisquare_test_statistics > critical_value:
    print("Reject the null hypothesis")
else:
    print("Accept the null hypothesis")
# Out:
# Chi-square statistic: 13.393665158371041
# p-value: 0.019956146695191457
# Reject the null hypothesis

# %% [markdown]
# # Q11

# %%
"""
A random sample of 30 people was selected from a population with an unknown mean and standard deviation. 
The sample mean was found to be 72 and the sample standard deviation was found to be 10. 
Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a significance level of 0.05.
"""

# %%
"""
To conduct the hypothesis test, we can use a one-sample t-test. 
The null hypothesis is that the population mean is equal to 70. 
The alternative hypothesis is that the population mean is significantly different from 70.

We can calculate the t-statistic using the formula:

t = (sample_mean - hypothesized_mean) / (sample_standard_deviation / sqrt(sample_size))

Substituting the given values, we get:

t = (72 - 70) / (10 / sqrt(30))
t = 1.095

Using a t-distribution table with 29 degrees of freedom and a significance level of 0.05, we find the critical values to be -2.045 and 2.045.

Since the calculated t-value of 1.095 falls within the range of -2.045 to 2.045, we fail to reject the null hypothesis. 
Therefore, we do not have enough evidence to conclude that the population mean is significantly different from 70 at a significance level of 0.05.
"""
